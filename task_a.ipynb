# %%
from task_a.task_a_plotter import plot_timing
from task_a.timing_function import timing

plot_timing(timing("./asap-dataset"))
